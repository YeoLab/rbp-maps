# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

# %%
tia1 = pd.read_table('/home/bay001/285_01_4000_TIA1.excluded.input_baseline.alt_cassette.normed_matrix.csv',
                    sep=',',index_col=0)

# %%
tia1.sum(axis=1).sort_values()
# Out:
# chr12:65672645-65720605:alt_cassette:+         0.012248
# chr3:62204657-62229480:alt_cassette:+          0.022378
# chr12:31079939-31116760:alt_cassette:+         0.024129
# chr10:117075246-117154168:alt_cassette:+       0.026921
# chr3:97251387-97329636:alt_cassette:+          0.027973
# chr14:26949349-27064615:alt_cassette:-         0.030263
# chr11:111414945-111425285:alt_cassette:+       0.033542
# chr11:85422275-85429832:alt_cassette:-         0.039640
# chr22:18043413-18062510:alt_cassette:+         0.039848
# chr7:87280253-87329736:alt_cassette:+          0.047408
# chr8:72246409-72268696:alt_cassette:-          0.047716
# chr6:133767892-133782251:alt_cassette:+        0.049728
# chr8:27779762-27845020:alt_cassette:-          0.050761
# chr11:8832882-8860856:alt_cassette:-           0.051027
# chrX:84520261-84523299:alt_cassette:+          0.052172
# chr1:10057389-10067627:alt_cassette:+          0.055420
# chr2:60689559-60773105:alt_cassette:-          0.057127
# ...

# %%
plt.figure(figsize=(20,10))
plt.plot(tia1.ix['chr4:119199947-119200543:alt_cassette:+'])
