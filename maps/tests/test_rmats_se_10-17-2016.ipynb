# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
wd = '/home/bay001/projects/maps_20160420/analysis/tests/rmats'
ipincluded = pd.read_table(os.path.join(wd,'204_01_RBFOX2.ip.included.feature.se.raw_density_matrix.csv'),sep=',',
                          index_col=0)

# %%
test = ipincluded.ix['10003\tENSG00000090539.11\tCHRD\tchr3\t+\t184105161\t184105200\t184104838\t184104895\t184105718\t184105821\t10003\t46,21\t26,0\t16,1\t4,3\t138\t100\t0.360867390803\t1.0\t0.562,1.0\t0.743,0.195\t0.312\n']

# %%
plt.plot(test)
