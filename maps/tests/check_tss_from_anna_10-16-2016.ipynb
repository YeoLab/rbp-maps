# %%
import pandas as pd

# %%
pd.read_table('/projects/ps-yeolab3/encode/transcript_regions/hg19v19/startCodon.human.V19.hg19.RNAseq.tsv')
# Out:
#                      #id  reference_sequence start_position  \
# chr10_100022776_-  chr10           100022776              -
# chr10_100174892_-  chr10           100174892              -
# chr10_100202997_-  chr10           100202997              -
# chr10_100995559_-  chr10           100995559              -
# chr10_101089145_+  chr10           101089145              +
# chr10_101090240_+  chr10           101090240              +
# chr10_101190033_-  chr10           101190033              -
# chr10_101190322_-  chr10           101190322              -
# chr10_101292889_+  chr10           101292889              +
# chr10_101380092_-  chr10           101380092              -
# chr10_101419714_+  chr10           101419714              +
# chr10_101491806_-  chr10           101491806              -
# chr10_101492106_+  chr10           101492106              +
# chr10_101499523_+  chr10           101499523              +
# chr10_101542602_+  chr10           101542602              +
# ...

# %%
pd.read_table('/projects/ps-yeolab3/encode/transcript_regions/hg19v19/startCodon.human.V19.hg19.single.tsv')
# Out:
#                      #id  reference_sequence start_position  \
# chr10_100022776_-  chr10           100022776              -
# chr10_100174892_-  chr10           100174892              -
# chr10_100202997_-  chr10           100202997              -
# chr10_100995559_-  chr10           100995559              -
# chr10_101089145_+  chr10           101089145              +
# chr10_101090240_+  chr10           101090240              +
# chr10_101190033_-  chr10           101190033              -
# chr10_101190322_-  chr10           101190322              -
# chr10_101292889_+  chr10           101292889              +
# chr10_101380092_-  chr10           101380092              -
# chr10_101419714_+  chr10           101419714              +
# chr10_101491806_-  chr10           101491806              -
# chr10_101492106_+  chr10           101492106              +
# chr10_101499523_+  chr10           101499523              +
# chr10_101542602_+  chr10           101542602              +
# ...
