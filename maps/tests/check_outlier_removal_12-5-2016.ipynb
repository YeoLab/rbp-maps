# %%
import pandas as pd
import numpy as np
import os

# %%
# number of CCNL1 overexpression events: 630
# number of CCNL1 overexpression exon events for RBP maps: 618
# Why?
wd = '/projects/ps-yeolab3/bay001/maps/current/se/'

# %%
rbfox2_raw = pd.read_table(os.path.join(wd,'204_01_RBFOX2.ip.background.feature.se.raw_density_matrix.csv'),
                                sep=',')
rbfox2_raw.head()
# Out:
#                                           Unnamed: 0         0         1  \
# 0  1\t"ENSG00000178665.10"\t"ZNF713"\tchr7\t+\t55...  0.233893  0.233893
# 1  100\t"ENSG00000100325.10"\t"ASCC2"\tchr22\t-\t...  0.233893  0.000000
# 2  10000\t"ENSG00000149548.10"\t"CCDC15"\tchr11\t...  0.000000  0.000000
# 3  10001\t"ENSG00000149548.10"\t"CCDC15"\tchr11\t...  0.000000  0.000000
# 4  10002\t"ENSG00000090539.11"\t"CHRD"\tchr3\t+\t...  3.274508  4.443975
#
#           2         3         4         5         6         7         8  \
# 0  0.233893  0.233893  0.233893  0.233893  0.233893  0.233893  0.233893
# 1  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4  4.911763  4.911763  4.677869  4.677869  4.677869  4.677869  4.911763
#
#      ...         1390      1391      1392      1393      1394      1395  \
# ...

# %%
rbfox2_raw.shape
# Out:
# (32823, 1401)

# %%
# Out:
# (1077, 1401)

# %%
pd.merge(ccnl1_rawdensity,ccnl1_normeddensity,how='outer',on="Unnamed: 0")
# Out:
#                                              Unnamed: 0       0_x       1_x  \
# 0     chr10:101124712:101124759:+@chr10:101128375:10... -1.000000 -1.000000
# 1     chr10:101419619:101419721:+@chr10:101420057:10...  0.157723  0.157723
# 2     chr10:104865463:104865558:-@chr10:104865115:10...  0.000000  0.000000
# 3     chr10:1094804:1095061:-@chr10:1089939:1090111:...  0.000000  0.000000
# 4     chr10:112004586:112004615:+@chr10:112020757:11... -1.000000 -1.000000
# 5     chr10:116247717:116247775:-@chr10:116245056:11...  0.473168  0.630890
# 6     chr10:118029015:118029098:-@chr10:117971143:11...  0.000000  0.000000
# 7     chr10:123892124:123892249:+@chr10:123903087:12...  0.000000  0.000000
# 8     chr10:134036145:134036276:-@chr10:134022799:13...  0.630890  0.630890
# 9     chr10:28149554:28149775:-@chr10:28142171:28142...  0.000000  0.000000
# 10    chr10:28822927:28822963:+@chr10:28823163:28823... -1.000000 -1.000000
# ...
